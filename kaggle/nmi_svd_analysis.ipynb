# %% [markdown]
# # NMI SVD Analysis v7 (aggressive torchao patch)

# %%
import subprocess, sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "transformers>=4.45", "peft>=0.12", "accelerate"])
print("OK")

# %%
import subprocess, sys, os, base64
script_b64 = '...'
script = base64.b64decode(script_b64).decode()
with open("run_nmi.py", "w") as f:
    f.write(script)
print(f"Wrote {len(script)} bytes")
result = subprocess.run([sys.executable, "-u", "run_nmi.py"],
                       timeout=7200)
print(f"Exit code: {result.returncode}")
