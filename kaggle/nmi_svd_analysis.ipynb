# %% [markdown]
# # NMI SVD Analysis Suite v3

# %%
import subprocess, sys
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'transformers>=4.45', 'peft>=0.12', 'accelerate'])
print('OK')

# %%
import base64
script = base64.b64decode('...').decode()
with open('a.py', 'w') as f: f.write(script)
print(f'Wrote {len(script)} bytes')

# %%
import subprocess
subprocess.run([sys.executable, '-u', 'a.py'], timeout=7200)
