# %% [markdown]
# # NMI Analysis Suite - SVD + Intervention + Dispersed Attacker
# Runs on GPU (T4/P100). ~30-60 min.

# %%
import subprocess, sys
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'transformers>=4.45', 'peft>=0.12', 'accelerate'])
print('Dependencies installed')

# %%
import base64, os
script = base64.b64decode('...').decode()
with open('nmi_analysis.py', 'w') as f:
    f.write(script)
print(f'Wrote {len(script)} bytes')

# %%
import subprocess, sys
result = subprocess.run([sys.executable, '-u', 'nmi_analysis.py'],
                       capture_output=False, timeout=7200)
print(f'Exit: {result.returncode}')
